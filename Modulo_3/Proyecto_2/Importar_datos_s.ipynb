# %% [markdown]
# # Proyecto 2. ÍNDICE DE CALIDAD DEL AIRE, SERIES DE TIEMPO

# %%
#Pusimos los archivos en la carpeta, vamos a trabajar con indice de calidad del aire
#http://www.aire.cdmx.gob.mx/default.php?opc=%27aqBjnmU=%27
#http://www.aire.cdmx.gob.mx/descargas/monitoreo/normatividad/NADF-009-AIRE-2017.pdf
#http://www.aire.cdmx.gob.mx/estadisticas-consultas/descargas/INDICExls-csv.pdf
#De esos links extrajo la información del excel
import pandas as pd
import os #Esta librería me permite manejar directorios y archivos
#Imaginemos que yo quiero leer los excel, pero vienen separados ¿cómo le hago, pues así:
data_2024 = pd.read_csv(r'./Original_dataset/imeca2024.csv')

# %%
data_2024
# Out:
#            Fecha  Hora  Noroeste ozono  Noroeste dióxido de azufre  \
# 0     01/01/2024     1            16.0                          14
# 1     01/01/2024     2             9.0                          14
# 2     01/01/2024     3             9.0                          12
# 3     01/01/2024     4            12.0                          12
# 4     01/01/2024     5            11.0                          12
# ...          ...   ...             ...                         ...
# 4326  29/06/2024    13            41.0                           2
# 4327  29/06/2024    14            44.0                           2
# 4328  29/06/2024    15            41.0                           2
# 4329  29/06/2024    16            36.0                           2
# 4330  29/06/2024    17            43.0                           2
#
#       Noroeste dióxido de nitrógeno  Noroeste monóxido de carbono  \
# 0                              20.0                          14.0
# 1                              20.0                          15.0
# 2                              19.0                          15.0
# 3                              19.0                          16.0
# 4                              18.0                          16.0
# ...                             ...                           ...
# 4326                           14.0                           8.0
# 4327                           10.0                           8.0
# 4328                            9.0                           7.0
# 4329                            7.0                           6.0
# 4330                           12.0                           6.0
#
#       Noroeste PM10  Noroeste PM25  Noreste ozono  Noreste dióxido de azufre  \
# 0                87           78.0           15.0                          8
# 1                94           82.0           10.0                          8
# 2               101           87.0            4.0                          8
# 3               105           89.0            5.0                         10
# 4               107           91.0            5.0                         10
# ...             ...            ...            ...                        ...
# 4326             39           63.0           42.0                          2
# 4327             39           63.0           43.0                          2
# 4328             39           62.0           42.0                          2
# 4329             36           64.0           33.0                          2
# 4330             34           62.0           39.0                          2
#
#       ...  Suroeste dióxido de nitrógeno  Suroeste monóxido de carbono  \
# 0     ...                           15.0                          11.0
# 1     ...                           14.0                          11.0
# 2     ...                           16.0                          12.0
# 3     ...                           14.0                          12.0
# 4     ...                           12.0                          12.0
# ...   ...                            ...                           ...
# 4326  ...                           10.0                           7.0
# 4327  ...                           11.0                           7.0
# 4328  ...                           10.0                           6.0
# 4329  ...                            8.0                           6.0
# 4330  ...                            8.0                           6.0
#
#       Suroeste PM10  Suroeste PM25  Sureste ozono  Sureste dióxido de azufre  \
# 0                38             64           21.0                          4
# 1                40             67           11.0                          4
# 2                40             67            5.0                          6
# 3                45             70            4.0                          6
# 4                50             70            6.0                          6
# ...             ...            ...            ...                        ...
# 4326             23             52           46.0                          6
# 4327             23             52           46.0                          6
# 4328             23             52           49.0                          6
# 4329             24             53           43.0                          6
# 4330             24             53           39.0                          6
#
#       Sureste dióxido de nitrógeno  Sureste monóxido de carbono  Sureste PM10  \
# 0                             21.0                         15.0          71.0
# 1                             20.0                         15.0          77.0
# 2                             21.0                         16.0          81.0
# 3                             20.0                         17.0          97.0
# 4                             19.0                         17.0         103.0
# ...                            ...                          ...           ...
# 4326                          11.0                          6.0          26.0
# 4327                           6.0                          6.0          28.0
# 4328                           6.0                          6.0          28.0
# 4329                           9.0                          5.0          28.0
# 4330                          10.0                          5.0          30.0
#
#       Sureste PM25
# 0               77
# 1               85
# 2               94
# 3              106
# 4              117
# ...            ...
# 4326            57
# 4327            58
# 4328            59
# 4329            60
# 4330            61
#
# [4331 rows x 32 columns]

# %%
data_2024.shape #Para el númerode filas y columnas
#Un problema que resulta que tenemos diversos archivos para cada año y no tengo los datos juntos, para no complicarnos hacemos lo siguiente
# Out:
# (4331, 32)

# %%
carpeta = r'./Original_dataset'

# %%
os.listdir(carpeta) #Me da la lista de archivos que hay en la carpeta
# Out:
# ['imeca2016.csv',
#  'imeca2017.csv',
#  'imeca2018.csv',
#  'imeca2019.csv',
#  'imeca2020.csv',
#  'imeca2021.csv',
#  'imeca2022.csv',
#  'imeca2023.csv',
#  'imeca2024.csv']

# %%
#Esto no es tan práctico porque me copia todos los datos
#dataframes = [ ]
#for archivo in os.listdir(carpeta): #Le aplicamo un ciclo for para que lea los archivos
   # df = pd.read_csv(carpeta + '/' + archivo) #Con esto le digo que una todos en un data frame
  #  dataframes.append(df) #Aquí le digo que una toddas las variables sin embargo me importa todos los datos y yo quiero que lea solamente unas variables de mi interés

# %%
dataframes = [ ]

for archivo in os.listdir(carpeta): #Le aplicamo un ciclo for para que lea los archivos
    df = pd.read_csv(carpeta + '/' + archivo) #Con esto le digo que una todos en un data frame
    columnas_primarias = ['Fecha', 'Hora' ] #Estas son mis variables de mi interés
    zonas = ['Noroeste', 'Noreste', 'Centro', 'Suroeste', 'Sureste'] #Estas son variables de la localización
    for zona in zonas: #Aplico el ciclo for para que me ponga esos datos de abajo para cada zona
        columnas_primarias.append(f'{zona} PM10') 
        columnas_primarias.append(f'{zona} monóxido de carbono')
    df_interes = df[columnas_primarias] #Aquí creo un data frame con mis variables de interés
    dataframes.append(df_interes)

df_comb=pd.concat(dataframes, ignore_index=True, axis=0)
df_comb.to_csv('Combinado.csv', index = False) #Con esto lo guardamos

# %%
df_comb
# Out:
#             Fecha  Hora  Noroeste PM10  Noroeste monóxido de carbono  \
# 0      01/01/2016     1            108                          13.0
# 1      01/01/2016     2            110                          13.0
# 2      01/01/2016     3            113                          14.0
# 3      01/01/2016     4            115                          14.0
# 4      01/01/2016     5            116                          15.0
# ...           ...   ...            ...                           ...
# 69318  29/06/2024    13             39                           8.0
# 69319  29/06/2024    14             39                           8.0
# 69320  29/06/2024    15             39                           7.0
# 69321  29/06/2024    16             36                           6.0
# 69322  29/06/2024    17             34                           6.0
#
#        Noreste PM10  Noreste monóxido de carbono  Centro PM10  \
# 0               117                         16.0          107
# 1               122                         18.0          107
# 2               124                         19.0          109
# 3               126                         19.0          110
# 4               127                         20.0          112
# ...             ...                          ...          ...
# 69318            39                          7.0           35
# 69319            39                          7.0           35
# 69320            39                          6.0           35
# 69321            39                          6.0           35
# 69322            39                          6.0           34
#
#        Centro monóxido de carbono  Suroeste PM10  \
# 0                            16.0             67
# 1                            17.0             70
# 2                            18.0             76
# 3                            19.0             83
# 4                            17.0             90
# ...                           ...            ...
# 69318                         8.0             23
# 69319                         8.0             23
# 69320                         7.0             23
# 69321                         7.0             24
# 69322                         6.0             24
#
#        Suroeste monóxido de carbono  Sureste PM10  Sureste monóxido de carbono
# 0                               9.0         107.0                         11.0
# 1                               9.0         107.0                         12.0
# 2                              10.0         108.0                         13.0
# 3                              10.0         107.0                         14.0
# 4                              11.0         108.0                         14.0
# ...                             ...           ...                          ...
# 69318                           7.0          26.0                          6.0
# 69319                           7.0          28.0                          6.0
# 69320                           6.0          28.0                          6.0
# 69321                           6.0          28.0                          5.0
# 69322                           6.0          30.0                          5.0
#
# [69323 rows x 12 columns]

# %%
df = pd.read_csv('Combinado.csv')

# %%
df.describe()
#Recordemos que el -99 es la codificación para un valor nulo, por ello le vamos a decir que no los lea
# Out:
#                Hora  Noroeste PM10  Noroeste monóxido de carbono  \
# count  69323.000000   69323.000000                  69264.000000
# mean      12.499834      67.921296                      1.977954
# std        6.921911      25.043909                     20.276814
# min        1.000000     -99.000000                    -99.000000
# 25%        7.000000      48.000000                      4.000000
# 50%       12.000000      65.000000                      5.000000
# 75%       18.000000      88.000000                      7.000000
# max       24.000000     142.000000                     43.000000
#
#        Noreste PM10  Noreste monóxido de carbono   Centro PM10  \
# count  69323.000000                 69264.000000  69323.000000
# mean      74.721031                     3.127483     58.138078
# std       31.815297                    20.304285     23.530954
# min      -99.000000                   -99.000000    -99.000000
# 25%       51.000000                     4.000000     40.000000
# 50%       77.000000                     5.000000     55.000000
# 75%      102.000000                     8.000000     74.000000
# max      166.000000                    64.000000    140.000000
#
#        Centro monóxido de carbono  Suroeste PM10  \
# count                69264.000000   69323.000000
# mean                     2.607762      41.921931
# std                     19.524339      19.556672
# min                    -99.000000     -99.000000
# 25%                      4.000000      30.000000
# 50%                      5.000000      40.000000
# 75%                      8.000000      52.000000
# max                     52.000000     115.000000
#
#        Suroeste monóxido de carbono  Sureste PM10  Sureste monóxido de carbono
# count                  69264.000000  69313.000000                 69264.000000
# mean                       0.597598     57.901663                     1.633302
# std                       19.885728     40.724041                    20.484189
# min                      -99.000000    -99.000000                   -99.000000
# 25%                        3.000000     40.000000                     4.000000
# 50%                        4.000000     60.000000                     5.000000
# 75%                        5.000000     84.000000                     7.000000
# max                       25.000000    132.000000                    36.000000

# %%
import numpy as np
df.replace(-99, np.nan, inplace = True )
#Puede ocurrir que en algún momento en alguna celda se nos ponga un valor de letras, por lo taqnto para resolver eso hacemos:

for col in df.columns[1:]: #Aquí le digo que me filtre
    df[col ] = pd.to_numeric(df[col ], errors='coerce')

df ['Fecha' ] = pd.to_datetime(df['Fecha' ], format = '%d/%m/%Y') #Aquí le digo cómo leer el formato de la fecha para que lo lea

# %%
df ['Fecha' ] = df ['Fecha' ].dt.strftime('%Y-%m-%d') #Así le indicamos a python el formato que queremos

# %%
df.head()
# Out:
#         Fecha  Hora  Noroeste PM10  Noroeste monóxido de carbono  \
# 0  2016-01-01     1          108.0                          13.0
# 1  2016-01-01     2          110.0                          13.0
# 2  2016-01-01     3          113.0                          14.0
# 3  2016-01-01     4          115.0                          14.0
# 4  2016-01-01     5          116.0                          15.0
#
#    Noreste PM10  Noreste monóxido de carbono  Centro PM10  \
# 0         117.0                         16.0        107.0
# 1         122.0                         18.0        107.0
# 2         124.0                         19.0        109.0
# 3         126.0                         19.0        110.0
# 4         127.0                         20.0        112.0
#
#    Centro monóxido de carbono  Suroeste PM10  Suroeste monóxido de carbono  \
# 0                        16.0           67.0                           9.0
# 1                        17.0           70.0                           9.0
# 2                        18.0           76.0                          10.0
# 3                        19.0           83.0                          10.0
# 4                        17.0           90.0                          11.0
#
#    Sureste PM10  Sureste monóxido de carbono
# 0         107.0                         11.0
# 1         107.0                         12.0
# 2         108.0                         13.0
# 3         107.0                         14.0
# 4         108.0                         14.0

# %%
#Me doy cuenta que aquí pandas me asigna la fecha y la hora, pero me repite la fecha, por lo tanto le vamos a agregar la hora a la fecha para que sea una etiqueta única
#Lo hago así
df['Hora' ] -= 1
df['Fecha_Hora' ] = pd.to_datetime(df['Fecha' ] + " " +df['Hora' ].astype(str) + ':00:00') #Me marca error de que no soporta el formato de hora, arriba muestro cómo resolverlo
#Me marcó error y tuve que convertir el formato como se muestra líneas arriba para que pudiera correr

# %%
df
# Out:
#             Fecha  Hora  Noroeste PM10  Noroeste monóxido de carbono  \
# 0      2016-01-01     0          108.0                          13.0
# 1      2016-01-01     1          110.0                          13.0
# 2      2016-01-01     2          113.0                          14.0
# 3      2016-01-01     3          115.0                          14.0
# 4      2016-01-01     4          116.0                          15.0
# ...           ...   ...            ...                           ...
# 69318  2024-06-29    12           39.0                           8.0
# 69319  2024-06-29    13           39.0                           8.0
# 69320  2024-06-29    14           39.0                           7.0
# 69321  2024-06-29    15           36.0                           6.0
# 69322  2024-06-29    16           34.0                           6.0
#
#        Noreste PM10  Noreste monóxido de carbono  Centro PM10  \
# 0             117.0                         16.0        107.0
# 1             122.0                         18.0        107.0
# 2             124.0                         19.0        109.0
# 3             126.0                         19.0        110.0
# 4             127.0                         20.0        112.0
# ...             ...                          ...          ...
# 69318          39.0                          7.0         35.0
# 69319          39.0                          7.0         35.0
# 69320          39.0                          6.0         35.0
# 69321          39.0                          6.0         35.0
# 69322          39.0                          6.0         34.0
#
#        Centro monóxido de carbono  Suroeste PM10  \
# 0                            16.0           67.0
# 1                            17.0           70.0
# 2                            18.0           76.0
# 3                            19.0           83.0
# 4                            17.0           90.0
# ...                           ...            ...
# 69318                         8.0           23.0
# 69319                         8.0           23.0
# 69320                         7.0           23.0
# 69321                         7.0           24.0
# 69322                         6.0           24.0
#
#        Suroeste monóxido de carbono  Sureste PM10  \
# 0                               9.0         107.0
# 1                               9.0         107.0
# 2                              10.0         108.0
# 3                              10.0         107.0
# 4                              11.0         108.0
# ...                             ...           ...
# 69318                           7.0          26.0
# 69319                           7.0          28.0
# 69320                           6.0          28.0
# 69321                           6.0          28.0
# 69322                           6.0          30.0
#
#        Sureste monóxido de carbono          Fecha_Hora
# 0                             11.0 2016-01-01 00:00:00
# 1                             12.0 2016-01-01 01:00:00
# 2                             13.0 2016-01-01 02:00:00
# 3                             14.0 2016-01-01 03:00:00
# 4                             14.0 2016-01-01 04:00:00
# ...                            ...                 ...
# 69318                          6.0 2024-06-29 12:00:00
# 69319                          6.0 2024-06-29 13:00:00
# 69320                          6.0 2024-06-29 14:00:00
# 69321                          5.0 2024-06-29 15:00:00
# 69322                          5.0 2024-06-29 16:00:00
#
# [69323 rows x 13 columns]

# %%
#Ahora le vamos a indicar
df.set_index('Fecha_Hora', inplace=True) #Aquí le digo a Pandas que la fecha y hora combinada será el formato de ordenamiento

# %%
df.head()
# Out:
#                           Fecha  Hora  Noroeste PM10  \
# Fecha_Hora
# 2016-01-01 00:00:00  2016-01-01     0          108.0
# 2016-01-01 01:00:00  2016-01-01     1          110.0
# 2016-01-01 02:00:00  2016-01-01     2          113.0
# 2016-01-01 03:00:00  2016-01-01     3          115.0
# 2016-01-01 04:00:00  2016-01-01     4          116.0
#
#                      Noroeste monóxido de carbono  Noreste PM10  \
# Fecha_Hora
# 2016-01-01 00:00:00                          13.0         117.0
# 2016-01-01 01:00:00                          13.0         122.0
# 2016-01-01 02:00:00                          14.0         124.0
# 2016-01-01 03:00:00                          14.0         126.0
# 2016-01-01 04:00:00                          15.0         127.0
#
#                      Noreste monóxido de carbono  Centro PM10  \
# Fecha_Hora
# 2016-01-01 00:00:00                         16.0        107.0
# 2016-01-01 01:00:00                         18.0        107.0
# 2016-01-01 02:00:00                         19.0        109.0
# 2016-01-01 03:00:00                         19.0        110.0
# 2016-01-01 04:00:00                         20.0        112.0
#
#                      Centro monóxido de carbono  Suroeste PM10  \
# Fecha_Hora
# 2016-01-01 00:00:00                        16.0           67.0
# 2016-01-01 01:00:00                        17.0           70.0
# 2016-01-01 02:00:00                        18.0           76.0
# 2016-01-01 03:00:00                        19.0           83.0
# 2016-01-01 04:00:00                        17.0           90.0
#
#                      Suroeste monóxido de carbono  Sureste PM10  \
# Fecha_Hora
# 2016-01-01 00:00:00                           9.0         107.0
# 2016-01-01 01:00:00                           9.0         107.0
# 2016-01-01 02:00:00                          10.0         108.0
# 2016-01-01 03:00:00                          10.0         107.0
# 2016-01-01 04:00:00                          11.0         108.0
#
#                      Sureste monóxido de carbono
# Fecha_Hora
# 2016-01-01 00:00:00                         11.0
# 2016-01-01 01:00:00                         12.0
# 2016-01-01 02:00:00                         13.0
# 2016-01-01 03:00:00                         14.0
# 2016-01-01 04:00:00                         14.0

# %%
#Aquí le digo que me ordene de menor a mayor, si yo quisiera que fuera al revés 8mayor a menor lo hago así:
#df.sort_index(inplace=True, ascending = True)
df.sort_index(inplace=True)

# %%
#Vamos a ponerle formato más entendible a nuestras columnas
short_name = {
    'Noroeste PM10' : 'NO-PM10',
    'Noroeste monóxido de carbono' : 'NO-CO',
    'Noreste PM10' : 'NE-PM10',
    'Noreste monóxido de carbono' : 'NE-CO',
    'Centro PM10' : 'CE-PM10',
    'Centro monóxido de carbono' : 'CE-CO',
    'Suroeste PM10' : 'SO-PM10',
    'Suroeste monóxido de carbono' : 'SO-CO',
    'Sureste PM10' : 'SE-PM10',
    'Sureste monóxido de carbono' : 'SE-CO'
}
df.rename(columns = short_name, inplace = True)

# %%
#Traemos la librería matl
import matplotlib.pyplot as plt

# %%
#Para ver si hay datos nulos
df.isnull().sum()
# Out:
# Fecha         0
# Hora          0
# NO-PM10      75
# NO-CO      2678
# NE-PM10     425
# NE-CO      2595
# CE-PM10      24
# CE-CO      2454
# SO-PM10     288
# SO-CO      2686
# SE-PM10    2674
# SE-CO      2759
# dtype: int64

# %%
#Hago esto para visualizar los datos nulos que tengo
nulos_por_año = df.isnull().groupby(df.index.year).sum()
nulos_por_año
# Out:
#             Fecha  Hora  NO-PM10  NO-CO  NE-PM10  NE-CO  CE-PM10  CE-CO  \
# Fecha_Hora
# 2016            0     0        0    366        0    366        0    366
# 2017            0     0        2    370       67    363        0    367
# 2018            0     0        0    364      179    364        0    364
# 2019            0     0       47    316       21    307        0    307
# 2020            0     0       26    374       43    373        5    375
# 2021            0     0        0    343       76    271        0    253
# 2022            0     0        0    318       39    330        0    291
# 2023            0     0        0    168        0    162       19     72
# 2024            0     0        0     59        0     59        0     59
#
#             SO-PM10  SO-CO  SE-PM10  SE-CO
# Fecha_Hora
# 2016              0    366       31    366
# 2017             46    362      883    369
# 2018              0    364      719    370
# 2019             36    307      314    301
# 2020             22    379      321    375
# 2021            107    297      120    353
# 2022             48    348      201    368
# 2023             29    204       75    198
# 2024              0     59       10     59

# %%
#Así los agrupo para que me dé por año y los nulos por mes
nulos_por_mes = df.isnull().groupby([ df.index.year,df.index.month ]).sum()

# %%
#nulos_por_mes #Así me muestra todo, pero puedo ver por etiqueta
nulos_por_mes.loc[ 2024]
# Out:
#             Fecha  Hora  NO-PM10  NO-CO  NE-PM10  NE-CO  CE-PM10  CE-CO  \
# Fecha_Hora
# 1               0     0        0     31        0     31        0     31
# 2               0     0        0     28        0     28        0     28
# 3               0     0        0      0        0      0        0      0
# 4               0     0        0      0        0      0        0      0
# 5               0     0        0      0        0      0        0      0
# 6               0     0        0      0        0      0        0      0
#
#             SO-PM10  SO-CO  SE-PM10  SE-CO
# Fecha_Hora
# 1                 0     31        0     31
# 2                 0     28        0     28
# 3                 0      0        0      0
# 4                 0      0        0      0
# 5                 0      0       10      0
# 6                 0      0        0      0

# %%
#Arriba me dice cuántos tengo, pero no me dice en qué rango de fechas está, para ello instalamos una librería
#%pip install missingno

# %%
import missingno as msno

# %%
#Con la librería de arriba ahora checo la distribución de los datos nulos
msno.matrix(df)
# Out:
# <Axes: >

# %%
plt.plot(df.index,df['NO-PM10' ]) #Se observa que no hay datos en un intervalo de 2023-2024, por ello hay que ver si hay datos nulos y eso lo hacemos como arriba

# %%
#Para ver los gráficos más bonitos nos pasaron un código por zoom
def plot_time_series(df, variable, zones, ylabel, title, start_date=None, end_date=None):
    plt.figure(figsize=(15, 5))
    if start_date and end_date:
        df = df.loc[start_date:end_date]
    
    for zone in zones:
        column = f"{zone}-{variable}"
        if column in df.columns:
            plt.plot(df.index, df[column], label=column)
        else:
            print(f"Columna {column} no encontrada en el DataFrame")
    plt.xlabel('Fecha_Hora')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_time_series(df,'PM10', ['NO' , 'CE', 'NE'], 'indice (PM10)', 'Serie de tiempo', start_date='2016-01-01', end_date='2019-12-30')
